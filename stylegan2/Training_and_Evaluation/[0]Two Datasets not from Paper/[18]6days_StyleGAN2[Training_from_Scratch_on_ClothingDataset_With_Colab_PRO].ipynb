# %% [markdown]
# From the continution to FILE: [14]StyleGAN2[Training_on_Clothing_Dataset_Without_Colab_Pro].ipynb
#
#
# FACT: This work is somewhat Novel on this dataset model. Till the date trained models are available here: https://github.com/justinpinkney/awesome-pretrained-stylegan2
#
# This work will add new model for Clothing GANs. Additionally, I will be releasing this for public domain as .pkl file as well.
#
# (Thanks to Colab Pro for training this awesome network for me! with exchange of $10 😛)
#
# GANs are beautiful!!

# %%
# %tensorflow_version 1.x
# !pip install opensimplex
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/stylegan2"
# Out:
# TensorFlow 1.x selected.
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/9c/ad/9b758f9ff9dcd23fc574bb3aa1de844adb1179c9be9711e9f798614d4b2f/opensimplex-0.3-py3-none-any.whl
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.3
# Mounted at /content/drive
# /content/drive/My Drive/stylegan2

# %%
# # Dont run this if you already have this clothing dataset file of 7GB in drive.
# api_token = {"username":"samy280497","key":"f80239517ec84712358a021a2389ffc4"}
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json


# import json

# with open('/root/.kaggle/kaggle.json', 'w') as file:
#     json.dump(api_token, file)

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d agrigorev/clothing-dataset-full

# %%
# !unzip clothing-dataset-full.zip

# %%
# !ls
# Out:
# clothing-dataset-full.zip  images_original  stylegan2

# %%
# Dont run this if you have already converted images
# %cd "/content/drive/My Drive/stylegan2/images_original"
#!/usr/bin/python
from PIL import Image
import os, sys

path = "/content/drive/My Drive/stylegan2/images_original/"
dirs = os.listdir(path)

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            im = im.convert('RGB')
            f, e = os.path.splitext(path+item)
            imResize = im.resize((1024,1024), Image.ANTIALIAS)
            imResize.save(f + '.jpg', 'JPEG', quality=90)

resize()
# Out:
# /content/drive/My Drive/stylegan2/images_original

# %%
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
#2nd argument is where to put your tfrecords files
#3rd should point at your image dataset
# !python dataset_tool.py create_from_images /content/drive/My\ Drive/stylegan2/stylegan2/datasets/images_original /content/drive/My\ Drive/stylegan2/images_original
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Loading images from "/content/drive/My Drive/stylegan2/images_original"
# 100% 5762/5762 [30:27<00:00,  3.15it/s]

# %%
# %cd "/content/drive/My Drive/stylegan2/stylegan2/datasets/images_original/"
# !ls
# Out:
# /content/drive/My Drive/stylegan2/stylegan2/datasets/images_original
# images_original-r02.tfrecords  images_original-r07.tfrecords
# images_original-r03.tfrecords  images_original-r08.tfrecords
# images_original-r04.tfrecords  images_original-r09.tfrecords
# images_original-r05.tfrecords  images_original-r10.tfrecords
# images_original-r06.tfrecords

# %%
# Training Day 1
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=images_original --mirror-augment=true --metrics=None
# Running metrics doesnt actually matter a lot as we will going to calculate the metrics fid50k standalone below cells as well.
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Local submit - run_dir: results/00001-stylegan2-images_original-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x8dcc000 @  0x7f12584a1001 0x7f1254f474ff 0x7f1254f97b08 0x7f1254f9bac7 0x7f125503a1a3 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7f106a422000 @  0x7f125849f1e7 0x7f1254f4741e 0x7f1254f97c2b 0x7f1254f9830f 0x7f125503a0a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f0f69420000 @  0x7f125849f1e7 0x7f1254f4741e 0x7f1254f97c2b 0x7f1254f9830f 0x7f11fe4a80c5 0x7f11fde2b902 0x7f11fde2beb2 0x7f11fdde4c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 1024, 1024]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00000-stylegan2-images_original-1gpu-config-f/network-snapshot-010016.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# lod                             -         ()                   -
# dlatent_avg                     -         (512,)               -
# G_mapping/latents_in            -         (?, 512)             -
# G_mapping/labels_in             -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# G_mapping/dlatents_out          -         (?, 18, 512)         -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/dlatents_in         -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# G_synthesis/images_out          -         (?, 3, 1024, 1024)   -
# G_synthesis/noise0              -         (1, 1, 4, 4)         -
# G_synthesis/noise1              -         (1, 1, 8, 8)         -
# G_synthesis/noise2              -         (1, 1, 8, 8)         -
# G_synthesis/noise3              -         (1, 1, 16, 16)       -
# G_synthesis/noise4              -         (1, 1, 16, 16)       -
# G_synthesis/noise5              -         (1, 1, 32, 32)       -
# G_synthesis/noise6              -         (1, 1, 32, 32)       -
# G_synthesis/noise7              -         (1, 1, 64, 64)       -
# G_synthesis/noise8              -         (1, 1, 64, 64)       -
# G_synthesis/noise9              -         (1, 1, 128, 128)     -
# G_synthesis/noise10             -         (1, 1, 128, 128)     -
# G_synthesis/noise11             -         (1, 1, 256, 256)     -
# G_synthesis/noise12             -         (1, 1, 256, 256)     -
# G_synthesis/noise13             -         (1, 1, 512, 512)     -
# G_synthesis/noise14             -         (1, 1, 512, 512)     -
# G_synthesis/noise15             -         (1, 1, 1024, 1024)   -
# G_synthesis/noise16             -         (1, 1, 1024, 1024)   -
# images_out                      -         (?, 3, 1024, 1024)   -
# ---                             ---       ---                  ---
# Total                           30370060
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# scores_out            -         (?, 1)               -
# ---                   ---       ---                  ---
# Total                 29012513
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 10016.1  lod 0.00  minibatch 32   time 2m 02s       sec/tick 122.3   sec/kimg 955.18  maintenance 0.0    gpumem 8.7
# tick 1     kimg 10020.2  lod 0.00  minibatch 32   time 16m 14s      sec/tick 819.4   sec/kimg 200.05  maintenance 32.5   gpumem 8.7
# tick 2     kimg 10024.3  lod 0.00  minibatch 32   time 30m 04s      sec/tick 818.5   sec/kimg 199.84  maintenance 11.2   gpumem 8.7
# tick 3     kimg 10028.4  lod 0.00  minibatch 32   time 43m 54s      sec/tick 818.2   sec/kimg 199.76  maintenance 12.1   gpumem 8.7
# tick 4     kimg 10032.5  lod 0.00  minibatch 32   time 57m 43s      sec/tick 817.7   sec/kimg 199.64  maintenance 11.6   gpumem 8.7
# tick 5     kimg 10036.6  lod 0.00  minibatch 32   time 1h 11m 33s   sec/tick 816.6   sec/kimg 199.36  maintenance 13.4   gpumem 8.7
# tick 6     kimg 10040.7  lod 0.00  minibatch 32   time 1h 25m 21s   sec/tick 815.8   sec/kimg 199.16  maintenance 11.4   gpumem 8.7
# tick 7     kimg 10044.8  lod 0.00  minibatch 32   time 1h 39m 08s   sec/tick 816.3   sec/kimg 199.29  maintenance 10.9   gpumem 8.7
# tick 8     kimg 10048.9  lod 0.00  minibatch 32   time 1h 52m 57s   sec/tick 817.9   sec/kimg 199.67  maintenance 11.4   gpumem 8.7
# tick 9     kimg 10053.0  lod 0.00  minibatch 32   time 2h 06m 47s   sec/tick 817.3   sec/kimg 199.54  maintenance 12.6   gpumem 8.7
# tick 10    kimg 10057.1  lod 0.00  minibatch 32   time 2h 20m 35s   sec/tick 817.1   sec/kimg 199.48  maintenance 11.0   gpumem 8.7
# tick 11    kimg 10061.2  lod 0.00  minibatch 32   time 2h 34m 24s   sec/tick 817.6   sec/kimg 199.60  maintenance 11.0   gpumem 8.7
# tick 12    kimg 10065.3  lod 0.00  minibatch 32   time 2h 48m 13s   sec/tick 818.3   sec/kimg 199.79  maintenance 10.8   gpumem 8.7
# tick 13    kimg 10069.4  lod 0.00  minibatch 32   time 3h 02m 05s   sec/tick 817.8   sec/kimg 199.66  maintenance 14.0   gpumem 8.7
# tick 14    kimg 10073.5  lod 0.00  minibatch 32   time 3h 15m 54s   sec/tick 818.4   sec/kimg 199.80  maintenance 11.5   gpumem 8.7
# tick 15    kimg 10077.6  lod 0.00  minibatch 32   time 3h 29m 45s   sec/tick 818.8   sec/kimg 199.91  maintenance 11.3   gpumem 8.7
# tick 16    kimg 10081.7  lod 0.00  minibatch 32   time 3h 43m 34s   sec/tick 818.8   sec/kimg 199.91  maintenance 11.1   gpumem 8.7
# tick 17    kimg 10085.8  lod 0.00  minibatch 32   time 3h 57m 26s   sec/tick 818.3   sec/kimg 199.78  maintenance 13.2   gpumem 8.7
# tick 18    kimg 10089.9  lod 0.00  minibatch 32   time 4h 11m 16s   sec/tick 818.8   sec/kimg 199.90  maintenance 11.5   gpumem 8.7
# tick 19    kimg 10094.0  lod 0.00  minibatch 32   time 4h 25m 06s   sec/tick 818.2   sec/kimg 199.75  maintenance 11.3   gpumem 8.7
# tick 20    kimg 10098.0  lod 0.00  minibatch 32   time 4h 38m 56s   sec/tick 818.7   sec/kimg 199.87  maintenance 11.5   gpumem 8.7
# tick 21    kimg 10102.1  lod 0.00  minibatch 32   time 4h 52m 47s   sec/tick 817.4   sec/kimg 199.56  maintenance 13.9   gpumem 8.7
# tick 22    kimg 10106.2  lod 0.00  minibatch 32   time 5h 06m 36s   sec/tick 817.9   sec/kimg 199.68  maintenance 11.3   gpumem 8.7
# tick 23    kimg 10110.3  lod 0.00  minibatch 32   time 5h 20m 26s   sec/tick 818.3   sec/kimg 199.78  maintenance 11.5   gpumem 8.7
# tick 24    kimg 10114.4  lod 0.00  minibatch 32   time 5h 34m 16s   sec/tick 818.3   sec/kimg 199.77  maintenance 11.3   gpumem 8.7
# tick 25    kimg 10118.5  lod 0.00  minibatch 32   time 5h 48m 07s   sec/tick 818.4   sec/kimg 199.81  maintenance 13.3   gpumem 8.7
# tick 26    kimg 10122.6  lod 0.00  minibatch 32   time 6h 01m 56s   sec/tick 817.6   sec/kimg 199.62  maintenance 11.2   gpumem 8.7
# tick 27    kimg 10126.7  lod 0.00  minibatch 32   time 6h 15m 46s   sec/tick 817.9   sec/kimg 199.68  maintenance 11.4   gpumem 8.7
# tick 28    kimg 10130.8  lod 0.00  minibatch 32   time 6h 29m 34s   sec/tick 817.6   sec/kimg 199.62  maintenance 10.9   gpumem 8.7
# tick 29    kimg 10134.9  lod 0.00  minibatch 32   time 6h 43m 31s   sec/tick 818.1   sec/kimg 199.74  maintenance 19.3   gpumem 8.7
# tick 30    kimg 10139.0  lod 0.00  minibatch 32   time 6h 57m 20s   sec/tick 817.3   sec/kimg 199.53  maintenance 11.1   gpumem 8.7
# tick 31    kimg 10143.1  lod 0.00  minibatch 32   time 7h 11m 08s   sec/tick 816.8   sec/kimg 199.42  maintenance 11.0   gpumem 8.7
# tick 32    kimg 10147.2  lod 0.00  minibatch 32   time 7h 24m 56s   sec/tick 817.4   sec/kimg 199.55  maintenance 11.0   gpumem 8.7
# tick 33    kimg 10151.3  lod 0.00  minibatch 32   time 7h 38m 47s   sec/tick 818.1   sec/kimg 199.73  maintenance 12.8   gpumem 8.7
# tick 34    kimg 10155.4  lod 0.00  minibatch 32   time 7h 52m 36s   sec/tick 817.8   sec/kimg 199.65  maintenance 10.8   gpumem 8.7
# tick 35    kimg 10159.5  lod 0.00  minibatch 32   time 8h 06m 24s   sec/tick 817.2   sec/kimg 199.51  maintenance 11.0   gpumem 8.7
# tick 36    kimg 10163.6  lod 0.00  minibatch 32   time 8h 20m 14s   sec/tick 818.1   sec/kimg 199.74  maintenance 12.6   gpumem 8.7
# tick 37    kimg 10167.7  lod 0.00  minibatch 32   time 8h 34m 05s   sec/tick 818.2   sec/kimg 199.76  maintenance 12.7   gpumem 8.7
# tick 38    kimg 10171.8  lod 0.00  minibatch 32   time 8h 47m 55s   sec/tick 818.4   sec/kimg 199.80  maintenance 11.0   gpumem 8.7
# tick 39    kimg 10175.9  lod 0.00  minibatch 32   time 9h 01m 44s   sec/tick 817.4   sec/kimg 199.56  maintenance 12.1   gpumem 8.7
# tick 40    kimg 10180.0  lod 0.00  minibatch 32   time 9h 15m 31s   sec/tick 816.5   sec/kimg 199.33  maintenance 10.7   gpumem 8.7
# tick 41    kimg 10184.1  lod 0.00  minibatch 32   time 9h 29m 20s   sec/tick 815.8   sec/kimg 199.17  maintenance 12.7   gpumem 8.7
# tick 42    kimg 10188.2  lod 0.00  minibatch 32   time 9h 43m 07s   sec/tick 815.9   sec/kimg 199.19  maintenance 11.0   gpumem 8.7
# tick 43    kimg 10192.3  lod 0.00  minibatch 32   time 9h 56m 55s   sec/tick 816.9   sec/kimg 199.43  maintenance 11.0   gpumem 8.7
# tick 44    kimg 10196.4  lod 0.00  minibatch 32   time 10h 10m 42s  sec/tick 816.2   sec/kimg 199.28  maintenance 11.0   gpumem 8.7
# tick 45    kimg 10200.4  lod 0.00  minibatch 32   time 10h 24m 31s  sec/tick 816.4   sec/kimg 199.32  maintenance 12.8   gpumem 8.7
# tick 46    kimg 10204.5  lod 0.00  minibatch 32   time 10h 38m 19s  sec/tick 816.7   sec/kimg 199.38  maintenance 10.8   gpumem 8.7
# tick 47    kimg 10208.6  lod 0.00  minibatch 32   time 10h 52m 07s  sec/tick 818.1   sec/kimg 199.74  maintenance 10.6   gpumem 8.7
# tick 48    kimg 10212.7  lod 0.00  minibatch 32   time 11h 05m 56s  sec/tick 817.3   sec/kimg 199.54  maintenance 11.2   gpumem 8.7
# tick 49    kimg 10216.8  lod 0.00  minibatch 32   time 11h 19m 46s  sec/tick 817.1   sec/kimg 199.49  maintenance 13.1   gpumem 8.7
# tick 50    kimg 10220.9  lod 0.00  minibatch 32   time 11h 33m 35s  sec/tick 817.8   sec/kimg 199.66  maintenance 10.7   gpumem 8.7
# tick 51    kimg 10225.0  lod 0.00  minibatch 32   time 11h 47m 24s  sec/tick 817.9   sec/kimg 199.68  maintenance 11.8   gpumem 8.7
# tick 52    kimg 10229.1  lod 0.00  minibatch 32   time 12h 01m 13s  sec/tick 817.3   sec/kimg 199.54  maintenance 11.0   gpumem 8.7
# tick 53    kimg 10233.2  lod 0.00  minibatch 32   time 12h 15m 03s  sec/tick 817.5   sec/kimg 199.58  maintenance 13.2   gpumem 8.7
# tick 54    kimg 10237.3  lod 0.00  minibatch 32   time 12h 28m 51s  sec/tick 816.8   sec/kimg 199.42  maintenance 10.8   gpumem 8.7
# tick 55    kimg 10241.4  lod 0.00  minibatch 32   time 12h 42m 40s  sec/tick 817.6   sec/kimg 199.60  maintenance 11.5   gpumem 8.7
# tick 56    kimg 10245.5  lod 0.00  minibatch 32   time 12h 56m 28s  sec/tick 816.7   sec/kimg 199.39  maintenance 11.2   gpumem 8.7
# tick 57    kimg 10249.6  lod 0.00  minibatch 32   time 13h 10m 17s  sec/tick 817.2   sec/kimg 199.50  maintenance 12.4   gpumem 8.7
# tick 58    kimg 10253.7  lod 0.00  minibatch 32   time 13h 24m 06s  sec/tick 817.2   sec/kimg 199.52  maintenance 10.8   gpumem 8.7
# tick 59    kimg 10257.8  lod 0.00  minibatch 32   time 13h 37m 54s  sec/tick 817.4   sec/kimg 199.56  maintenance 10.9   gpumem 8.7
# tick 60    kimg 10261.9  lod 0.00  minibatch 32   time 13h 51m 42s  sec/tick 816.7   sec/kimg 199.38  maintenance 11.4   gpumem 8.7
# tick 61    kimg 10266.0  lod 0.00  minibatch 32   time 14h 05m 32s  sec/tick 817.2   sec/kimg 199.51  maintenance 12.4   gpumem 8.7
# tick 62    kimg 10270.1  lod 0.00  minibatch 32   time 14h 19m 20s  sec/tick 817.1   sec/kimg 199.48  maintenance 11.1   gpumem 8.7
# tick 63    kimg 10274.2  lod 0.00  minibatch 32   time 14h 33m 08s  sec/tick 817.2   sec/kimg 199.50  maintenance 10.8   gpumem 8.7
# tick 64    kimg 10278.3  lod 0.00  minibatch 32   time 14h 46m 56s  sec/tick 817.5   sec/kimg 199.59  maintenance 10.9   gpumem 8.7
# tick 65    kimg 10282.4  lod 0.00  minibatch 32   time 15h 00m 46s  sec/tick 816.9   sec/kimg 199.43  maintenance 13.5   gpumem 8.7
# tick 66    kimg 10286.5  lod 0.00  minibatch 32   time 15h 14m 34s  sec/tick 817.0   sec/kimg 199.47  maintenance 10.8   gpumem 8.7
# tick 67    kimg 10290.6  lod 0.00  minibatch 32   time 15h 28m 24s  sec/tick 817.7   sec/kimg 199.63  maintenance 11.8   gpumem 8.7
# tick 68    kimg 10294.7  lod 0.00  minibatch 32   time 15h 42m 12s  sec/tick 816.9   sec/kimg 199.44  maintenance 10.9   gpumem 8.7
# tick 69    kimg 10298.8  lod 0.00  minibatch 32   time 15h 56m 01s  sec/tick 816.7   sec/kimg 199.38  maintenance 12.7   gpumem 8.7
# tick 70    kimg 10302.8  lod 0.00  minibatch 32   time 16h 09m 50s  sec/tick 818.0   sec/kimg 199.71  maintenance 11.1   gpumem 8.7
# tick 71    kimg 10306.9  lod 0.00  minibatch 32   time 16h 23m 39s  sec/tick 818.0   sec/kimg 199.70  maintenance 11.1   gpumem 8.7
# tick 72    kimg 10311.0  lod 0.00  minibatch 32   time 16h 37m 29s  sec/tick 818.8   sec/kimg 199.91  maintenance 11.3   gpumem 8.7
# tick 73    kimg 10315.1  lod 0.00  minibatch 32   time 16h 51m 21s  sec/tick 818.1   sec/kimg 199.72  maintenance 13.8   gpumem 8.7
# tick 74    kimg 10319.2  lod 0.00  minibatch 32   time 17h 05m 14s  sec/tick 820.4   sec/kimg 200.29  maintenance 12.4   gpumem 8.7
# tick 75    kimg 10323.3  lod 0.00  minibatch 32   time 17h 19m 05s  sec/tick 819.5   sec/kimg 200.07  maintenance 11.7   gpumem 8.7
# tick 76    kimg 10327.4  lod 0.00  minibatch 32   time 17h 32m 55s  sec/tick 818.4   sec/kimg 199.81  maintenance 12.0   gpumem 8.7
# tick 77    kimg 10331.5  lod 0.00  minibatch 32   time 17h 46m 50s  sec/tick 820.1   sec/kimg 200.21  maintenance 14.1   gpumem 8.7
# tick 78    kimg 10335.6  lod 0.00  minibatch 32   time 18h 00m 42s  sec/tick 820.3   sec/kimg 200.26  maintenance 12.1   gpumem 8.7
# tick 79    kimg 10339.7  lod 0.00  minibatch 32   time 18h 14m 31s  sec/tick 817.2   sec/kimg 199.51  maintenance 12.1   gpumem 8.7
# tick 80    kimg 10343.8  lod 0.00  minibatch 32   time 18h 28m 19s  sec/tick 816.5   sec/kimg 199.35  maintenance 11.0   gpumem 8.7
# tick 81    kimg 10347.9  lod 0.00  minibatch 32   time 18h 42m 19s  sec/tick 820.7   sec/kimg 200.36  maintenance 19.8   gpumem 8.7
# tick 82    kimg 10352.0  lod 0.00  minibatch 32   time 18h 56m 11s  sec/tick 819.5   sec/kimg 200.06  maintenance 11.9   gpumem 8.7
# tick 83    kimg 10356.1  lod 0.00  minibatch 32   time 19h 10m 00s  sec/tick 817.6   sec/kimg 199.61  maintenance 11.4   gpumem 8.7
# tick 84    kimg 10360.2  lod 0.00  minibatch 32   time 19h 23m 49s  sec/tick 818.1   sec/kimg 199.73  maintenance 11.4   gpumem 8.7
# tick 85    kimg 10364.3  lod 0.00  minibatch 32   time 19h 37m 40s  sec/tick 818.1   sec/kimg 199.73  maintenance 13.2   gpumem 8.7
# tick 86    kimg 10368.4  lod 0.00  minibatch 32   time 19h 51m 29s  sec/tick 816.9   sec/kimg 199.43  maintenance 11.3   gpumem 8.7

# %% [markdown]
# # Loading networks from "results/00001-stylegan2-images_original-1gpu-config-f/network-snapshot-010360.pkl"...

# %%
# Training Day 2
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=images_original --mirror-augment=true --metrics=None
# Running metrics doesnt actually matter a lot as we will going to calculate the metrics fid50k standalone below cells as well.
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Local submit - run_dir: results/00002-stylegan2-images_original-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x7c4c000 @  0x7f6a67e1e001 0x7f6a648c44ff 0x7f6a64914b08 0x7f6a64918ac7 0x7f6a649b71a3 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7f687a422000 @  0x7f6a67e1c1e7 0x7f6a648c441e 0x7f6a64914c2b 0x7f6a6491530f 0x7f6a649b70a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f6779420000 @  0x7f6a67e1c1e7 0x7f6a648c441e 0x7f6a64914c2b 0x7f6a6491530f 0x7f6a0de250c5 0x7f6a0d7a8902 0x7f6a0d7a8eb2 0x7f6a0d761c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 1024, 1024]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00001-stylegan2-images_original-1gpu-config-f/network-snapshot-010360.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# lod                             -         ()                   -
# dlatent_avg                     -         (512,)               -
# G_mapping/latents_in            -         (?, 512)             -
# G_mapping/labels_in             -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# G_mapping/dlatents_out          -         (?, 18, 512)         -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/dlatents_in         -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# G_synthesis/images_out          -         (?, 3, 1024, 1024)   -
# G_synthesis/noise0              -         (1, 1, 4, 4)         -
# G_synthesis/noise1              -         (1, 1, 8, 8)         -
# G_synthesis/noise2              -         (1, 1, 8, 8)         -
# G_synthesis/noise3              -         (1, 1, 16, 16)       -
# G_synthesis/noise4              -         (1, 1, 16, 16)       -
# G_synthesis/noise5              -         (1, 1, 32, 32)       -
# G_synthesis/noise6              -         (1, 1, 32, 32)       -
# G_synthesis/noise7              -         (1, 1, 64, 64)       -
# G_synthesis/noise8              -         (1, 1, 64, 64)       -
# G_synthesis/noise9              -         (1, 1, 128, 128)     -
# G_synthesis/noise10             -         (1, 1, 128, 128)     -
# G_synthesis/noise11             -         (1, 1, 256, 256)     -
# G_synthesis/noise12             -         (1, 1, 256, 256)     -
# G_synthesis/noise13             -         (1, 1, 512, 512)     -
# G_synthesis/noise14             -         (1, 1, 512, 512)     -
# G_synthesis/noise15             -         (1, 1, 1024, 1024)   -
# G_synthesis/noise16             -         (1, 1, 1024, 1024)   -
# images_out                      -         (?, 3, 1024, 1024)   -
# ---                             ---       ---                  ---
# Total                           30370060
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# scores_out            -         (?, 1)               -
# ---                   ---       ---                  ---
# Total                 29012513
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 10360.1  lod 0.00  minibatch 32   time 2m 29s       sec/tick 148.6   sec/kimg 1161.13 maintenance 0.0    gpumem 8.6
# tick 1     kimg 10364.2  lod 0.00  minibatch 32   time 34m 34s      sec/tick 1897.8  sec/kimg 463.33  maintenance 27.5   gpumem 8.6
# tick 2     kimg 10368.3  lod 0.00  minibatch 32   time 1h 06m 23s   sec/tick 1898.0  sec/kimg 463.37  maintenance 11.3   gpumem 8.6
# tick 3     kimg 10372.4  lod 0.00  minibatch 32   time 1h 38m 12s   sec/tick 1897.4  sec/kimg 463.22  maintenance 11.4   gpumem 8.6
# tick 4     kimg 10376.5  lod 0.00  minibatch 32   time 2h 10m 01s   sec/tick 1897.5  sec/kimg 463.26  maintenance 11.3   gpumem 8.6
# tick 5     kimg 10380.6  lod 0.00  minibatch 32   time 2h 41m 51s   sec/tick 1897.9  sec/kimg 463.34  maintenance 12.9   gpumem 8.6
# tick 6     kimg 10384.7  lod 0.00  minibatch 32   time 3h 13m 40s   sec/tick 1897.5  sec/kimg 463.26  maintenance 11.3   gpumem 8.6
# tick 7     kimg 10388.8  lod 0.00  minibatch 32   time 3h 45m 29s   sec/tick 1897.4  sec/kimg 463.23  maintenance 11.2   gpumem 8.6
# tick 8     kimg 10392.9  lod 0.00  minibatch 32   time 4h 17m 18s   sec/tick 1897.5  sec/kimg 463.25  maintenance 11.2   gpumem 8.6
# tick 9     kimg 10397.0  lod 0.00  minibatch 32   time 4h 49m 10s   sec/tick 1898.6  sec/kimg 463.53  maintenance 13.3   gpumem 8.6
# tick 10    kimg 10401.1  lod 0.00  minibatch 32   time 5h 21m 00s   sec/tick 1899.2  sec/kimg 463.66  maintenance 11.6   gpumem 8.6
# tick 11    kimg 10405.2  lod 0.00  minibatch 32   time 5h 52m 50s   sec/tick 1898.2  sec/kimg 463.42  maintenance 11.5   gpumem 8.6
# tick 12    kimg 10409.3  lod 0.00  minibatch 32   time 6h 24m 39s   sec/tick 1897.9  sec/kimg 463.36  maintenance 11.1   gpumem 8.6
# tick 13    kimg 10413.4  lod 0.00  minibatch 32   time 6h 56m 33s   sec/tick 1899.5  sec/kimg 463.76  maintenance 14.0   gpumem 8.6
# tick 14    kimg 10417.5  lod 0.00  minibatch 32   time 7h 28m 25s   sec/tick 1900.1  sec/kimg 463.89  maintenance 12.0   gpumem 8.6
# tick 15    kimg 10421.6  lod 0.00  minibatch 32   time 8h 00m 17s   sec/tick 1900.6  sec/kimg 464.01  maintenance 12.0   gpumem 8.6
# tick 16    kimg 10425.7  lod 0.00  minibatch 32   time 8h 32m 09s   sec/tick 1900.2  sec/kimg 463.92  maintenance 11.9   gpumem 8.6
# tick 17    kimg 10429.8  lod 0.00  minibatch 32   time 9h 04m 04s   sec/tick 1900.2  sec/kimg 463.92  maintenance 14.4   gpumem 8.6
# tick 18    kimg 10433.9  lod 0.00  minibatch 32   time 9h 35m 54s   sec/tick 1898.4  sec/kimg 463.48  maintenance 11.7   gpumem 8.6
# tick 19    kimg 10438.0  lod 0.00  minibatch 32   time 10h 07m 46s  sec/tick 1900.0  sec/kimg 463.88  maintenance 11.4   gpumem 8.6
# tick 20    kimg 10442.0  lod 0.00  minibatch 32   time 10h 39m 37s  sec/tick 1899.4  sec/kimg 463.71  maintenance 11.6   gpumem 8.6
# tick 21    kimg 10446.1  lod 0.00  minibatch 32   time 11h 11m 27s  sec/tick 1897.3  sec/kimg 463.22  maintenance 13.0   gpumem 8.6
# tick 22    kimg 10450.2  lod 0.00  minibatch 32   time 11h 43m 16s  sec/tick 1898.0  sec/kimg 463.38  maintenance 11.2   gpumem 8.6
# tick 23    kimg 10454.3  lod 0.00  minibatch 32   time 12h 15m 04s  sec/tick 1897.2  sec/kimg 463.19  maintenance 11.1   gpumem 8.6
# tick 24    kimg 10458.4  lod 0.00  minibatch 32   time 12h 46m 53s  sec/tick 1897.3  sec/kimg 463.22  maintenance 11.1   gpumem 8.6
# tick 25    kimg 10462.5  lod 0.00  minibatch 32   time 13h 18m 43s  sec/tick 1897.5  sec/kimg 463.25  maintenance 12.8   gpumem 8.6
# tick 26    kimg 10466.6  lod 0.00  minibatch 32   time 13h 50m 32s  sec/tick 1897.6  sec/kimg 463.29  maintenance 11.2   gpumem 8.6
# tick 27    kimg 10470.7  lod 0.00  minibatch 32   time 14h 22m 21s  sec/tick 1897.4  sec/kimg 463.23  maintenance 11.2   gpumem 8.6
# tick 28    kimg 10474.8  lod 0.00  minibatch 32   time 14h 54m 09s  sec/tick 1897.4  sec/kimg 463.24  maintenance 11.1   gpumem 8.6
# tick 29    kimg 10478.9  lod 0.00  minibatch 32   time 15h 26m 00s  sec/tick 1898.0  sec/kimg 463.38  maintenance 13.0   gpumem 8.6
# tick 30    kimg 10483.0  lod 0.00  minibatch 32   time 15h 57m 51s  sec/tick 1898.8  sec/kimg 463.58  maintenance 11.7   gpumem 8.6
# tick 31    kimg 10487.1  lod 0.00  minibatch 32   time 16h 29m 42s  sec/tick 1899.5  sec/kimg 463.74  maintenance 11.7   gpumem 8.6
# tick 32    kimg 10491.2  lod 0.00  minibatch 32   time 17h 01m 33s  sec/tick 1899.8  sec/kimg 463.81  maintenance 11.8   gpumem 8.6
# tick 33    kimg 10495.3  lod 0.00  minibatch 32   time 17h 33m 26s  sec/tick 1899.5  sec/kimg 463.74  maintenance 13.3   gpumem 8.6
# tick 34    kimg 10499.4  lod 0.00  minibatch 32   time 18h 05m 17s  sec/tick 1899.1  sec/kimg 463.64  maintenance 11.7   gpumem 8.6
# tick 35    kimg 10503.5  lod 0.00  minibatch 32   time 18h 37m 06s  sec/tick 1898.0  sec/kimg 463.38  maintenance 11.4   gpumem 8.6
# tick 36    kimg 10507.6  lod 0.00  minibatch 32   time 19h 08m 57s  sec/tick 1898.2  sec/kimg 463.42  maintenance 12.2   gpumem 8.6
# tick 37    kimg 10511.7  lod 0.00  minibatch 32   time 19h 40m 48s  sec/tick 1897.8  sec/kimg 463.32  maintenance 13.0   gpumem 8.6

# %% [markdown]
# ##Loading networks from "results/00002-stylegan2-images_original-1gpu-config-f/network-snapshot-010507.pkl"...

# %%
# DAY 3
# Training Day 3
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=images_original --mirror-augment=true --metrics=None
# Running metrics doesnt actually matter a lot as we will going to calculate the metrics fid50k standalone below cells as well.
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Local submit - run_dir: results/00003-stylegan2-images_original-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x72b0000 @  0x7f85d9d37001 0x7f85d67dd4ff 0x7f85d682db08 0x7f85d6831ac7 0x7f85d68d01a3 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7f83ec422000 @  0x7f85d9d351e7 0x7f85d67dd41e 0x7f85d682dc2b 0x7f85d682e30f 0x7f85d68d00a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f82eb420000 @  0x7f85d9d351e7 0x7f85d67dd41e 0x7f85d682dc2b 0x7f85d682e30f 0x7f857fd3e0c5 0x7f857f6c1902 0x7f857f6c1eb2 0x7f857f67ac3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 1024, 1024]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00002-stylegan2-images_original-1gpu-config-f/network-snapshot-010507.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# lod                             -         ()                   -
# dlatent_avg                     -         (512,)               -
# G_mapping/latents_in            -         (?, 512)             -
# G_mapping/labels_in             -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# G_mapping/dlatents_out          -         (?, 18, 512)         -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/dlatents_in         -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# G_synthesis/images_out          -         (?, 3, 1024, 1024)   -
# G_synthesis/noise0              -         (1, 1, 4, 4)         -
# G_synthesis/noise1              -         (1, 1, 8, 8)         -
# G_synthesis/noise2              -         (1, 1, 8, 8)         -
# G_synthesis/noise3              -         (1, 1, 16, 16)       -
# G_synthesis/noise4              -         (1, 1, 16, 16)       -
# G_synthesis/noise5              -         (1, 1, 32, 32)       -
# G_synthesis/noise6              -         (1, 1, 32, 32)       -
# G_synthesis/noise7              -         (1, 1, 64, 64)       -
# G_synthesis/noise8              -         (1, 1, 64, 64)       -
# G_synthesis/noise9              -         (1, 1, 128, 128)     -
# G_synthesis/noise10             -         (1, 1, 128, 128)     -
# G_synthesis/noise11             -         (1, 1, 256, 256)     -
# G_synthesis/noise12             -         (1, 1, 256, 256)     -
# G_synthesis/noise13             -         (1, 1, 512, 512)     -
# G_synthesis/noise14             -         (1, 1, 512, 512)     -
# G_synthesis/noise15             -         (1, 1, 1024, 1024)   -
# G_synthesis/noise16             -         (1, 1, 1024, 1024)   -
# images_out                      -         (?, 3, 1024, 1024)   -
# ---                             ---       ---                  ---
# Total                           30370060
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# scores_out            -         (?, 1)               -
# ---                   ---       ---                  ---
# Total                 29012513
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 10507.1  lod 0.00  minibatch 32   time 2m 29s       sec/tick 149.1   sec/kimg 1164.48 maintenance 0.0    gpumem 8.6
# tick 1     kimg 10511.2  lod 0.00  minibatch 32   time 34m 31s      sec/tick 1895.8  sec/kimg 462.85  maintenance 26.5   gpumem 8.6
# tick 2     kimg 10515.3  lod 0.00  minibatch 32   time 1h 06m 17s   sec/tick 1894.4  sec/kimg 462.51  maintenance 11.3   gpumem 8.6
# tick 3     kimg 10519.4  lod 0.00  minibatch 32   time 1h 38m 04s   sec/tick 1895.3  sec/kimg 462.71  maintenance 11.4   gpumem 8.6
# tick 4     kimg 10523.5  lod 0.00  minibatch 32   time 2h 09m 50s   sec/tick 1895.3  sec/kimg 462.71  maintenance 11.1   gpumem 8.6
# tick 5     kimg 10527.6  lod 0.00  minibatch 32   time 2h 41m 39s   sec/tick 1896.0  sec/kimg 462.88  maintenance 12.9   gpumem 8.6
# tick 6     kimg 10531.7  lod 0.00  minibatch 32   time 3h 13m 26s   sec/tick 1895.5  sec/kimg 462.76  maintenance 11.2   gpumem 8.6
# tick 7     kimg 10535.8  lod 0.00  minibatch 32   time 3h 45m 13s   sec/tick 1895.6  sec/kimg 462.78  maintenance 11.3   gpumem 8.6
# tick 8     kimg 10539.9  lod 0.00  minibatch 32   time 4h 16m 59s   sec/tick 1895.1  sec/kimg 462.68  maintenance 11.2   gpumem 8.6
# tick 9     kimg 10544.0  lod 0.00  minibatch 32   time 4h 48m 46s   sec/tick 1894.1  sec/kimg 462.43  maintenance 12.8   gpumem 8.6
# tick 10    kimg 10548.1  lod 0.00  minibatch 32   time 5h 20m 31s   sec/tick 1894.0  sec/kimg 462.41  maintenance 11.2   gpumem 8.6
# tick 11    kimg 10552.2  lod 0.00  minibatch 32   time 5h 52m 16s   sec/tick 1893.7  sec/kimg 462.32  maintenance 11.0   gpumem 8.6
# tick 12    kimg 10556.3  lod 0.00  minibatch 32   time 6h 24m 01s   sec/tick 1894.4  sec/kimg 462.49  maintenance 10.9   gpumem 8.6
# tick 13    kimg 10560.4  lod 0.00  minibatch 32   time 6h 55m 48s   sec/tick 1893.6  sec/kimg 462.30  maintenance 13.0   gpumem 8.6
# tick 14    kimg 10564.5  lod 0.00  minibatch 32   time 7h 27m 33s   sec/tick 1894.2  sec/kimg 462.45  maintenance 11.0   gpumem 8.6
# tick 15    kimg 10568.6  lod 0.00  minibatch 32   time 7h 59m 20s   sec/tick 1895.7  sec/kimg 462.81  maintenance 11.3   gpumem 8.6
# tick 16    kimg 10572.7  lod 0.00  minibatch 32   time 8h 31m 06s   sec/tick 1895.5  sec/kimg 462.77  maintenance 11.0   gpumem 8.6
# tick 17    kimg 10576.8  lod 0.00  minibatch 32   time 9h 02m 55s   sec/tick 1895.1  sec/kimg 462.66  maintenance 13.6   gpumem 8.6
# tick 18    kimg 10580.9  lod 0.00  minibatch 32   time 9h 34m 40s   sec/tick 1894.0  sec/kimg 462.41  maintenance 11.1   gpumem 8.6
# tick 19    kimg 10585.0  lod 0.00  minibatch 32   time 10h 06m 25s  sec/tick 1894.1  sec/kimg 462.42  maintenance 11.0   gpumem 8.6
# tick 20    kimg 10589.0  lod 0.00  minibatch 32   time 10h 38m 09s  sec/tick 1893.2  sec/kimg 462.21  maintenance 11.1   gpumem 8.6
# tick 21    kimg 10593.1  lod 0.00  minibatch 32   time 11h 09m 56s  sec/tick 1893.3  sec/kimg 462.23  maintenance 13.0   gpumem 8.6
# tick 22    kimg 10597.2  lod 0.00  minibatch 32   time 11h 41m 40s  sec/tick 1893.9  sec/kimg 462.38  maintenance 11.0   gpumem 8.6
# tick 23    kimg 10601.3  lod 0.00  minibatch 32   time 12h 13m 25s  sec/tick 1893.4  sec/kimg 462.27  maintenance 10.8   gpumem 8.6
# tick 24    kimg 10605.4  lod 0.00  minibatch 32   time 12h 45m 09s  sec/tick 1893.1  sec/kimg 462.19  maintenance 11.1   gpumem 8.6
# tick 25    kimg 10609.5  lod 0.00  minibatch 32   time 13h 16m 55s  sec/tick 1893.7  sec/kimg 462.32  maintenance 12.7   gpumem 8.6
# tick 26    kimg 10613.6  lod 0.00  minibatch 32   time 13h 48m 41s  sec/tick 1894.1  sec/kimg 462.43  maintenance 11.0   gpumem 8.6
# tick 27    kimg 10617.7  lod 0.00  minibatch 32   time 14h 20m 26s  sec/tick 1894.0  sec/kimg 462.41  maintenance 11.0   gpumem 8.6
# tick 28    kimg 10621.8  lod 0.00  minibatch 32   time 14h 52m 10s  sec/tick 1893.6  sec/kimg 462.30  maintenance 11.1   gpumem 8.6
# tick 29    kimg 10625.9  lod 0.00  minibatch 32   time 15h 23m 58s  sec/tick 1895.3  sec/kimg 462.73  maintenance 12.9   gpumem 8.6
# tick 30    kimg 10630.0  lod 0.00  minibatch 32   time 15h 55m 45s  sec/tick 1895.5  sec/kimg 462.77  maintenance 11.2   gpumem 8.6
# tick 31    kimg 10634.1  lod 0.00  minibatch 32   time 16h 27m 32s  sec/tick 1895.7  sec/kimg 462.81  maintenance 11.3   gpumem 8.6
# tick 32    kimg 10638.2  lod 0.00  minibatch 32   time 16h 59m 19s  sec/tick 1896.1  sec/kimg 462.90  maintenance 11.3   gpumem 8.6
# tick 33    kimg 10642.3  lod 0.00  minibatch 32   time 17h 31m 08s  sec/tick 1895.7  sec/kimg 462.83  maintenance 12.7   gpumem 8.6
# tick 34    kimg 10646.4  lod 0.00  minibatch 32   time 18h 02m 55s  sec/tick 1895.6  sec/kimg 462.79  maintenance 11.3   gpumem 8.6
# tick 35    kimg 10650.5  lod 0.00  minibatch 32   time 18h 34m 42s  sec/tick 1895.6  sec/kimg 462.79  maintenance 11.2   gpumem 8.6
# tick 36    kimg 10654.6  lod 0.00  minibatch 32   time 19h 06m 30s  sec/tick 1896.0  sec/kimg 462.89  maintenance 11.9   gpumem 8.6
# tick 37    kimg 10658.7  lod 0.00  minibatch 32   time 19h 38m 18s  sec/tick 1895.3  sec/kimg 462.73  maintenance 12.9   gpumem 8.6

# %% [markdown]
# ##Loading networks from "results/00003-stylegan2-images_original-1gpu-config-f/network-snapshot-010654.pkl"...

# %%
# DAY 4
# Training Day 4
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=images_original --mirror-augment=true --metrics=None
# Running metrics doesnt actually matter a lot as we will going to calculate the metrics fid50k standalone below cells as well.
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Local submit - run_dir: results/00004-stylegan2-images_original-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x74be000 @  0x7fd1c2f95001 0x7fd1bfa3b4ff 0x7fd1bfa8bb08 0x7fd1bfa8fac7 0x7fd1bfb2e1a3 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7fcfd52c8000 @  0x7fd1c2f931e7 0x7fd1bfa3b41e 0x7fd1bfa8bc2b 0x7fd1bfa8c30f 0x7fd1bfb2e0a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7fced42c6000 @  0x7fd1c2f931e7 0x7fd1bfa3b41e 0x7fd1bfa8bc2b 0x7fd1bfa8c30f 0x7fd168f9c0c5 0x7fd16891f902 0x7fd16891feb2 0x7fd1688d8c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 1024, 1024]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00003-stylegan2-images_original-1gpu-config-f/network-snapshot-010654.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# lod                             -         ()                   -
# dlatent_avg                     -         (512,)               -
# G_mapping/latents_in            -         (?, 512)             -
# G_mapping/labels_in             -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# G_mapping/dlatents_out          -         (?, 18, 512)         -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/dlatents_in         -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# G_synthesis/images_out          -         (?, 3, 1024, 1024)   -
# G_synthesis/noise0              -         (1, 1, 4, 4)         -
# G_synthesis/noise1              -         (1, 1, 8, 8)         -
# G_synthesis/noise2              -         (1, 1, 8, 8)         -
# G_synthesis/noise3              -         (1, 1, 16, 16)       -
# G_synthesis/noise4              -         (1, 1, 16, 16)       -
# G_synthesis/noise5              -         (1, 1, 32, 32)       -
# G_synthesis/noise6              -         (1, 1, 32, 32)       -
# G_synthesis/noise7              -         (1, 1, 64, 64)       -
# G_synthesis/noise8              -         (1, 1, 64, 64)       -
# G_synthesis/noise9              -         (1, 1, 128, 128)     -
# G_synthesis/noise10             -         (1, 1, 128, 128)     -
# G_synthesis/noise11             -         (1, 1, 256, 256)     -
# G_synthesis/noise12             -         (1, 1, 256, 256)     -
# G_synthesis/noise13             -         (1, 1, 512, 512)     -
# G_synthesis/noise14             -         (1, 1, 512, 512)     -
# G_synthesis/noise15             -         (1, 1, 1024, 1024)   -
# G_synthesis/noise16             -         (1, 1, 1024, 1024)   -
# images_out                      -         (?, 3, 1024, 1024)   -
# ---                             ---       ---                  ---
# Total                           30370060
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# scores_out            -         (?, 1)               -
# ---                   ---       ---                  ---
# Total                 29012513
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 10654.1  lod 0.00  minibatch 32   time 2m 34s       sec/tick 153.6   sec/kimg 1199.70 maintenance 0.0    gpumem 8.6
# tick 1     kimg 10658.2  lod 0.00  minibatch 32   time 34m 51s      sec/tick 1905.3  sec/kimg 465.17  maintenance 31.8   gpumem 8.6
# tick 2     kimg 10662.3  lod 0.00  minibatch 32   time 1h 06m 48s   sec/tick 1904.8  sec/kimg 465.05  maintenance 12.2   gpumem 8.6
# tick 3     kimg 10666.4  lod 0.00  minibatch 32   time 1h 38m 43s   sec/tick 1903.1  sec/kimg 464.62  maintenance 12.2   gpumem 8.6
# tick 4     kimg 10670.5  lod 0.00  minibatch 32   time 2h 10m 38s   sec/tick 1903.4  sec/kimg 464.69  maintenance 12.1   gpumem 8.6
# tick 5     kimg 10674.6  lod 0.00  minibatch 32   time 2h 42m 38s   sec/tick 1905.0  sec/kimg 465.08  maintenance 15.0   gpumem 8.6
# tick 6     kimg 10678.7  lod 0.00  minibatch 32   time 3h 14m 36s   sec/tick 1904.5  sec/kimg 464.96  maintenance 13.0   gpumem 8.6
# tick 7     kimg 10682.8  lod 0.00  minibatch 32   time 3h 46m 33s   sec/tick 1904.1  sec/kimg 464.86  maintenance 13.0   gpumem 8.6
# tick 8     kimg 10686.9  lod 0.00  minibatch 32   time 4h 18m 29s   sec/tick 1903.9  sec/kimg 464.83  maintenance 12.1   gpumem 8.6
# tick 9     kimg 10691.0  lod 0.00  minibatch 32   time 4h 50m 28s   sec/tick 1904.7  sec/kimg 465.00  maintenance 14.8   gpumem 8.6
# tick 10    kimg 10695.1  lod 0.00  minibatch 32   time 5h 22m 26s   sec/tick 1904.3  sec/kimg 464.93  maintenance 12.9   gpumem 8.6
# tick 11    kimg 10699.2  lod 0.00  minibatch 32   time 5h 54m 21s   sec/tick 1902.6  sec/kimg 464.50  maintenance 12.3   gpumem 8.6
# tick 12    kimg 10703.3  lod 0.00  minibatch 32   time 6h 26m 15s   sec/tick 1902.8  sec/kimg 464.56  maintenance 11.8   gpumem 8.6
# tick 13    kimg 10707.4  lod 0.00  minibatch 32   time 6h 58m 13s   sec/tick 1902.7  sec/kimg 464.53  maintenance 14.6   gpumem 8.6
# tick 14    kimg 10711.5  lod 0.00  minibatch 32   time 7h 30m 06s   sec/tick 1901.1  sec/kimg 464.13  maintenance 11.9   gpumem 8.6
# tick 15    kimg 10715.6  lod 0.00  minibatch 32   time 8h 01m 57s   sec/tick 1900.1  sec/kimg 463.88  maintenance 11.6   gpumem 8.6
# tick 16    kimg 10719.7  lod 0.00  minibatch 32   time 8h 33m 49s   sec/tick 1900.2  sec/kimg 463.92  maintenance 11.1   gpumem 8.6
# tick 17    kimg 10723.8  lod 0.00  minibatch 32   time 9h 05m 46s   sec/tick 1903.5  sec/kimg 464.73  maintenance 13.8   gpumem 8.6
# tick 18    kimg 10727.9  lod 0.00  minibatch 32   time 9h 37m 41s   sec/tick 1902.9  sec/kimg 464.57  maintenance 12.1   gpumem 8.6
# tick 19    kimg 10732.0  lod 0.00  minibatch 32   time 10h 09m 37s  sec/tick 1903.3  sec/kimg 464.67  maintenance 12.5   gpumem 8.6
# tick 20    kimg 10736.0  lod 0.00  minibatch 32   time 10h 41m 34s  sec/tick 1904.5  sec/kimg 464.96  maintenance 12.6   gpumem 8.6
# tick 21    kimg 10740.1  lod 0.00  minibatch 32   time 11h 13m 34s  sec/tick 1904.7  sec/kimg 465.01  maintenance 15.5   gpumem 8.6
# tick 22    kimg 10744.2  lod 0.00  minibatch 32   time 11h 45m 30s  sec/tick 1903.6  sec/kimg 464.73  maintenance 12.3   gpumem 8.6
# tick 23    kimg 10748.3  lod 0.00  minibatch 32   time 12h 17m 24s  sec/tick 1901.9  sec/kimg 464.32  maintenance 12.4   gpumem 8.6
# tick 24    kimg 10752.4  lod 0.00  minibatch 32   time 12h 49m 16s  sec/tick 1900.3  sec/kimg 463.94  maintenance 11.8   gpumem 8.6
# tick 25    kimg 10756.5  lod 0.00  minibatch 32   time 13h 21m 10s  sec/tick 1900.0  sec/kimg 463.87  maintenance 14.2   gpumem 8.6
# tick 26    kimg 10760.6  lod 0.00  minibatch 32   time 13h 53m 01s  sec/tick 1899.5  sec/kimg 463.75  maintenance 11.6   gpumem 8.6
# tick 27    kimg 10764.7  lod 0.00  minibatch 32   time 14h 24m 55s  sec/tick 1902.0  sec/kimg 464.36  maintenance 11.5   gpumem 8.6
# tick 28    kimg 10768.8  lod 0.00  minibatch 32   time 14h 56m 51s  sec/tick 1903.3  sec/kimg 464.67  maintenance 12.2   gpumem 8.6
# tick 29    kimg 10772.9  lod 0.00  minibatch 32   time 15h 28m 50s  sec/tick 1904.6  sec/kimg 465.00  maintenance 15.1   gpumem 8.6
# tick 30    kimg 10777.0  lod 0.00  minibatch 32   time 16h 00m 46s  sec/tick 1903.5  sec/kimg 464.73  maintenance 12.3   gpumem 8.6
# tick 31    kimg 10781.1  lod 0.00  minibatch 32   time 16h 32m 42s  sec/tick 1903.7  sec/kimg 464.77  maintenance 12.6   gpumem 8.6
# tick 32    kimg 10785.2  lod 0.00  minibatch 32   time 17h 04m 40s  sec/tick 1905.1  sec/kimg 465.12  maintenance 12.4   gpumem 8.6
# tick 33    kimg 10789.3  lod 0.00  minibatch 32   time 17h 36m 39s  sec/tick 1903.7  sec/kimg 464.76  maintenance 14.9   gpumem 8.6
# tick 34    kimg 10793.4  lod 0.00  minibatch 32   time 18h 08m 33s  sec/tick 1902.8  sec/kimg 464.54  maintenance 12.0   gpumem 8.6
# tick 35    kimg 10797.5  lod 0.00  minibatch 32   time 18h 40m 29s  sec/tick 1903.7  sec/kimg 464.77  maintenance 12.0   gpumem 8.6
# tick 36    kimg 10801.6  lod 0.00  minibatch 32   time 19h 12m 27s  sec/tick 1905.1  sec/kimg 465.11  maintenance 13.0   gpumem 8.6
# tick 37    kimg 10805.7  lod 0.00  minibatch 32   time 19h 44m 26s  sec/tick 1904.0  sec/kimg 464.85  maintenance 14.6   gpumem 8.6

# %% [markdown]
# Loading networks from "results/00004-stylegan2-images_original-1gpu-config-f/network-snapshot-010801.pkl"...

# %%
# DAY 5
# Training Day 5
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=images_original --mirror-augment=true --metrics=None
# Running metrics doesnt actually matter a lot as we will going to calculate the metrics fid50k standalone below cells as well.
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Local submit - run_dir: results/00005-stylegan2-images_original-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x8a68000 @  0x7fd0ea3ac001 0x7fd0e6e524ff 0x7fd0e6ea2b08 0x7fd0e6ea6ac7 0x7fd0e6f451a3 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7fcefcc24000 @  0x7fd0ea3aa1e7 0x7fd0e6e5241e 0x7fd0e6ea2c2b 0x7fd0e6ea330f 0x7fd0e6f450a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7fcdfbc22000 @  0x7fd0ea3aa1e7 0x7fd0e6e5241e 0x7fd0e6ea2c2b 0x7fd0e6ea330f 0x7fd0903b30c5 0x7fd08fd36902 0x7fd08fd36eb2 0x7fd08fcefc3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 1024, 1024]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00004-stylegan2-images_original-1gpu-config-f/network-snapshot-010801.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# lod                             -         ()                   -
# dlatent_avg                     -         (512,)               -
# G_mapping/latents_in            -         (?, 512)             -
# G_mapping/labels_in             -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# G_mapping/dlatents_out          -         (?, 18, 512)         -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/dlatents_in         -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# G_synthesis/images_out          -         (?, 3, 1024, 1024)   -
# G_synthesis/noise0              -         (1, 1, 4, 4)         -
# G_synthesis/noise1              -         (1, 1, 8, 8)         -
# G_synthesis/noise2              -         (1, 1, 8, 8)         -
# G_synthesis/noise3              -         (1, 1, 16, 16)       -
# G_synthesis/noise4              -         (1, 1, 16, 16)       -
# G_synthesis/noise5              -         (1, 1, 32, 32)       -
# G_synthesis/noise6              -         (1, 1, 32, 32)       -
# G_synthesis/noise7              -         (1, 1, 64, 64)       -
# G_synthesis/noise8              -         (1, 1, 64, 64)       -
# G_synthesis/noise9              -         (1, 1, 128, 128)     -
# G_synthesis/noise10             -         (1, 1, 128, 128)     -
# G_synthesis/noise11             -         (1, 1, 256, 256)     -
# G_synthesis/noise12             -         (1, 1, 256, 256)     -
# G_synthesis/noise13             -         (1, 1, 512, 512)     -
# G_synthesis/noise14             -         (1, 1, 512, 512)     -
# G_synthesis/noise15             -         (1, 1, 1024, 1024)   -
# G_synthesis/noise16             -         (1, 1, 1024, 1024)   -
# images_out                      -         (?, 3, 1024, 1024)   -
# ---                             ---       ---                  ---
# Total                           30370060
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# scores_out            -         (?, 1)               -
# ---                   ---       ---                  ---
# Total                 29012513
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 10801.1  lod 0.00  minibatch 32   time 2m 31s       sec/tick 151.1   sec/kimg 1180.75 maintenance 0.0    gpumem 8.5
# tick 1     kimg 10805.2  lod 0.00  minibatch 32   time 34m 42s      sec/tick 1903.0  sec/kimg 464.60  maintenance 27.4   gpumem 8.5
# tick 2     kimg 10809.3  lod 0.00  minibatch 32   time 1h 06m 36s   sec/tick 1903.0  sec/kimg 464.61  maintenance 11.9   gpumem 8.5
# tick 3     kimg 10813.4  lod 0.00  minibatch 32   time 1h 38m 31s   sec/tick 1902.6  sec/kimg 464.50  maintenance 12.1   gpumem 8.5
# tick 4     kimg 10817.5  lod 0.00  minibatch 32   time 2h 10m 26s   sec/tick 1902.5  sec/kimg 464.48  maintenance 12.1   gpumem 8.5
# tick 5     kimg 10821.6  lod 0.00  minibatch 32   time 2h 42m 23s   sec/tick 1903.2  sec/kimg 464.64  maintenance 14.4   gpumem 8.5
# tick 6     kimg 10825.7  lod 0.00  minibatch 32   time 3h 14m 17s   sec/tick 1902.6  sec/kimg 464.50  maintenance 11.5   gpumem 8.5
# tick 7     kimg 10829.8  lod 0.00  minibatch 32   time 3h 46m 12s   sec/tick 1902.9  sec/kimg 464.58  maintenance 11.6   gpumem 8.5
# tick 8     kimg 10833.9  lod 0.00  minibatch 32   time 4h 18m 07s   sec/tick 1903.4  sec/kimg 464.70  maintenance 11.8   gpumem 8.5
# tick 9     kimg 10838.0  lod 0.00  minibatch 32   time 4h 50m 04s   sec/tick 1902.7  sec/kimg 464.54  maintenance 13.7   gpumem 8.5
# tick 10    kimg 10842.1  lod 0.00  minibatch 32   time 5h 21m 58s   sec/tick 1902.7  sec/kimg 464.54  maintenance 11.7   gpumem 8.5
# tick 11    kimg 10846.2  lod 0.00  minibatch 32   time 5h 53m 53s   sec/tick 1902.8  sec/kimg 464.55  maintenance 11.9   gpumem 8.5
# tick 12    kimg 10850.3  lod 0.00  minibatch 32   time 6h 25m 48s   sec/tick 1904.0  sec/kimg 464.85  maintenance 11.5   gpumem 8.5
# tick 13    kimg 10854.4  lod 0.00  minibatch 32   time 6h 57m 45s   sec/tick 1902.9  sec/kimg 464.57  maintenance 13.4   gpumem 8.5
# tick 14    kimg 10858.5  lod 0.00  minibatch 32   time 7h 29m 39s   sec/tick 1902.8  sec/kimg 464.54  maintenance 11.8   gpumem 8.5
# tick 15    kimg 10862.6  lod 0.00  minibatch 32   time 8h 01m 34s   sec/tick 1903.4  sec/kimg 464.69  maintenance 11.7   gpumem 8.5
# tick 16    kimg 10866.7  lod 0.00  minibatch 32   time 8h 33m 29s   sec/tick 1903.2  sec/kimg 464.65  maintenance 11.9   gpumem 8.5
# tick 17    kimg 10870.8  lod 0.00  minibatch 32   time 9h 05m 26s   sec/tick 1902.9  sec/kimg 464.57  maintenance 13.5   gpumem 8.5
# tick 18    kimg 10874.9  lod 0.00  minibatch 32   time 9h 37m 20s   sec/tick 1902.5  sec/kimg 464.47  maintenance 11.5   gpumem 8.5
# tick 19    kimg 10879.0  lod 0.00  minibatch 32   time 10h 09m 15s  sec/tick 1903.8  sec/kimg 464.80  maintenance 11.5   gpumem 8.5
# tick 20    kimg 10883.0  lod 0.00  minibatch 32   time 10h 41m 10s  sec/tick 1902.9  sec/kimg 464.58  maintenance 11.7   gpumem 8.5
# tick 21    kimg 10887.1  lod 0.00  minibatch 32   time 11h 13m 06s  sec/tick 1902.5  sec/kimg 464.49  maintenance 13.6   gpumem 8.5
# tick 22    kimg 10891.2  lod 0.00  minibatch 32   time 11h 45m 01s  sec/tick 1903.3  sec/kimg 464.67  maintenance 11.6   gpumem 8.5
# tick 23    kimg 10895.3  lod 0.00  minibatch 32   time 12h 16m 55s  sec/tick 1902.7  sec/kimg 464.53  maintenance 11.8   gpumem 8.5
# tick 24    kimg 10899.4  lod 0.00  minibatch 32   time 12h 48m 49s  sec/tick 1902.1  sec/kimg 464.38  maintenance 11.3   gpumem 8.5
# tick 25    kimg 10903.5  lod 0.00  minibatch 32   time 13h 20m 43s  sec/tick 1901.9  sec/kimg 464.33  maintenance 12.9   gpumem 8.5
# tick 26    kimg 10907.6  lod 0.00  minibatch 32   time 13h 52m 38s  sec/tick 1902.7  sec/kimg 464.54  maintenance 11.4   gpumem 8.5
# tick 27    kimg 10911.7  lod 0.00  minibatch 32   time 14h 24m 31s  sec/tick 1902.2  sec/kimg 464.40  maintenance 11.6   gpumem 8.5
# tick 28    kimg 10915.8  lod 0.00  minibatch 32   time 14h 56m 25s  sec/tick 1902.2  sec/kimg 464.40  maintenance 11.5   gpumem 8.5
# tick 29    kimg 10919.9  lod 0.00  minibatch 32   time 15h 28m 21s  sec/tick 1902.9  sec/kimg 464.59  maintenance 13.4   gpumem 8.5
# tick 30    kimg 10924.0  lod 0.00  minibatch 32   time 16h 00m 16s  sec/tick 1902.1  sec/kimg 464.38  maintenance 12.0   gpumem 8.5
# tick 31    kimg 10928.1  lod 0.00  minibatch 32   time 16h 32m 07s  sec/tick 1900.6  sec/kimg 464.02  maintenance 11.3   gpumem 8.5
# tick 32    kimg 10932.2  lod 0.00  minibatch 32   time 17h 03m 59s  sec/tick 1900.6  sec/kimg 464.01  maintenance 11.2   gpumem 8.5
# tick 33    kimg 10936.3  lod 0.00  minibatch 32   time 17h 35m 52s  sec/tick 1900.0  sec/kimg 463.86  maintenance 12.5   gpumem 8.5
# tick 34    kimg 10940.4  lod 0.00  minibatch 32   time 18h 07m 44s  sec/tick 1901.0  sec/kimg 464.12  maintenance 11.2   gpumem 8.5
# tick 35    kimg 10944.5  lod 0.00  minibatch 32   time 18h 39m 36s  sec/tick 1901.1  sec/kimg 464.15  maintenance 11.3   gpumem 8.5
# tick 36    kimg 10948.6  lod 0.00  minibatch 32   time 19h 11m 30s  sec/tick 1901.5  sec/kimg 464.24  maintenance 12.3   gpumem 8.5
# tick 37    kimg 10952.7  lod 0.00  minibatch 32   time 19h 43m 22s  sec/tick 1899.1  sec/kimg 463.65  maintenance 12.8   gpumem 8.5

# %%
# DAY 6
# Training Day 6
# %cd "/content/drive/My Drive/stylegan2/stylegan2/"
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=images_original --mirror-augment=true --metrics=None
# Running metrics doesnt actually matter a lot as we will going to calculate the metrics fid50k standalone below cells as well.
# Out:
# /content/drive/My Drive/stylegan2/stylegan2
# Local submit - run_dir: results/00006-stylegan2-images_original-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x91f6000 @  0x7f3fda57f001 0x7f3fd70254ff 0x7f3fd7075b08 0x7f3fd7079ac7 0x7f3fd71181a3 0x50a4a5 0x50cc96 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588e5c 0x59fd0e
# tcmalloc: large alloc 4294967296 bytes == 0x7f3decc24000 @  0x7f3fda57d1e7 0x7f3fd702541e 0x7f3fd7075c2b 0x7f3fd707630f 0x7f3fd71180a3 0x50a4a5 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4
# tcmalloc: large alloc 4294967296 bytes == 0x7f3cebc22000 @  0x7f3fda57d1e7 0x7f3fd702541e 0x7f3fd7075c2b 0x7f3fd707630f 0x7f3f805860c5 0x7f3f7ff09902 0x7f3f7ff09eb2 0x7f3f7fec2c3e 0x50a12f 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x588c8b 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x508ec2 0x594a01
# Dataset shape = [3, 1024, 1024]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "results/00005-stylegan2-images_original-1gpu-config-f/network-snapshot-010948.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# lod                             -         ()                   -
# dlatent_avg                     -         (512,)               -
# G_mapping/latents_in            -         (?, 512)             -
# G_mapping/labels_in             -         (?, 0)               -
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Dense2                262656    (?, 512)             (512, 512)
# G_mapping/Dense3                262656    (?, 512)             (512, 512)
# G_mapping/Dense4                262656    (?, 512)             (512, 512)
# G_mapping/Dense5                262656    (?, 512)             (512, 512)
# G_mapping/Dense6                262656    (?, 512)             (512, 512)
# G_mapping/Dense7                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# G_mapping/dlatents_out          -         (?, 18, 512)         -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/dlatents_in         -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# G_synthesis/images_out          -         (?, 3, 1024, 1024)   -
# G_synthesis/noise0              -         (1, 1, 4, 4)         -
# G_synthesis/noise1              -         (1, 1, 8, 8)         -
# G_synthesis/noise2              -         (1, 1, 8, 8)         -
# G_synthesis/noise3              -         (1, 1, 16, 16)       -
# G_synthesis/noise4              -         (1, 1, 16, 16)       -
# G_synthesis/noise5              -         (1, 1, 32, 32)       -
# G_synthesis/noise6              -         (1, 1, 32, 32)       -
# G_synthesis/noise7              -         (1, 1, 64, 64)       -
# G_synthesis/noise8              -         (1, 1, 64, 64)       -
# G_synthesis/noise9              -         (1, 1, 128, 128)     -
# G_synthesis/noise10             -         (1, 1, 128, 128)     -
# G_synthesis/noise11             -         (1, 1, 256, 256)     -
# G_synthesis/noise12             -         (1, 1, 256, 256)     -
# G_synthesis/noise13             -         (1, 1, 512, 512)     -
# G_synthesis/noise14             -         (1, 1, 512, 512)     -
# G_synthesis/noise15             -         (1, 1, 1024, 1024)   -
# G_synthesis/noise16             -         (1, 1, 1024, 1024)   -
# images_out                      -         (?, 3, 1024, 1024)   -
# ---                             ---       ---                  ---
# Total                           30370060
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# scores_out            -         (?, 1)               -
# ---                   ---       ---                  ---
# Total                 29012513
#
# Building TensorFlow graph...
# Initializing logs...
# Training for 25000 kimg...
#
# tick 0     kimg 10948.1  lod 0.00  minibatch 32   time 1m 59s       sec/tick 119.2   sec/kimg 930.96  maintenance 0.0    gpumem 8.6
# tick 1     kimg 10952.2  lod 0.00  minibatch 32   time 16m 11s      sec/tick 823.7   sec/kimg 201.10  maintenance 28.2   gpumem 8.6
# tick 2     kimg 10956.3  lod 0.00  minibatch 32   time 30m 07s      sec/tick 825.2   sec/kimg 201.46  maintenance 11.1   gpumem 8.6
# tick 3     kimg 10960.4  lod 0.00  minibatch 32   time 44m 03s      sec/tick 824.5   sec/kimg 201.28  maintenance 11.0   gpumem 8.6
# tick 4     kimg 10964.5  lod 0.00  minibatch 32   time 57m 57s      sec/tick 823.6   sec/kimg 201.07  maintenance 10.6   gpumem 8.6
# tick 5     kimg 10968.6  lod 0.00  minibatch 32   time 1h 11m 54s   sec/tick 825.1   sec/kimg 201.44  maintenance 12.3   gpumem 8.6
# tick 6     kimg 10972.7  lod 0.00  minibatch 32   time 1h 25m 50s   sec/tick 824.8   sec/kimg 201.37  maintenance 11.0   gpumem 8.6
# tick 7     kimg 10976.8  lod 0.00  minibatch 32   time 1h 39m 46s   sec/tick 824.9   sec/kimg 201.40  maintenance 10.6   gpumem 8.6
# tick 8     kimg 10980.9  lod 0.00  minibatch 32   time 1h 53m 42s   sec/tick 824.9   sec/kimg 201.39  maintenance 10.8   gpumem 8.6
# tick 9     kimg 10985.0  lod 0.00  minibatch 32   time 2h 07m 39s   sec/tick 824.2   sec/kimg 201.23  maintenance 13.3   gpumem 8.6
# tick 10    kimg 10989.1  lod 0.00  minibatch 32   time 2h 21m 33s   sec/tick 823.7   sec/kimg 201.11  maintenance 10.6   gpumem 8.6
# tick 11    kimg 10993.2  lod 0.00  minibatch 32   time 2h 35m 27s   sec/tick 823.2   sec/kimg 200.98  maintenance 10.8   gpumem 8.6
# Traceback (most recent call last):
#   File "run_training.py", line 202, in <module>
#     main()
#   File "run_training.py", line 197, in main
#     run(**vars(args))
#   File "run_training.py", line 128, in run
#     dnnlib.submit_run(**kwargs)
#   File "/content/drive/My Drive/stylegan2/stylegan2/dnnlib/submission/submit.py", line 343, in submit_run
#     return farm.submit(submit_config, host_run_dir)
#   File "/content/drive/My Drive/stylegan2/stylegan2/dnnlib/submission/internal/local.py", line 22, in submit
#     return run_wrapper(submit_config)
#   File "/content/drive/My Drive/stylegan2/stylegan2/dnnlib/submission/submit.py", line 280, in run_wrapper
#     run_func_obj(**submit_config.run_func_kwargs)
#   File "/content/drive/My Drive/stylegan2/stylegan2/training/training_loop.py", line 305, in training_loop
#     tflib.run(G_reg_op, feed_dict)
#   File "/content/drive/My Drive/stylegan2/stylegan2/dnnlib/tflib/tfutil.py", line 31, in run
#     return tf.get_default_session().run(*args, **kwargs)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt
